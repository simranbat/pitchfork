# %% [markdown]
# Create TFIDF matrix and save a reduced version for PCA

# %% [markdown]
# Simran Batra

# %% [markdown]
# DS 5559

# %% [markdown]
# # Configuration

# %%
db_name = 'pitchfork.db'
db_name2 = "pitchfork_adjectives"

OHCO = ['Title', 'Artist', 'Score', 'Date','Genre', 'Author', 'para_num', 'sent_num', 'token_num']
TITLE = OHCO[:1]
ARTIST = OHCO[:2]
SCORE = OHCO[:3]
DATE = OHCO[:4]
GENRE = OHCO[:5]
AUTHOR = OHCO[:6]
PARAS = OHCO[:7]
SENTS = OHCO[:8]

BAG = AUTHOR

# %% [markdown]
# ## Libraries

# %%
import sqlite3
import pandas as pd
import numpy as np

# %% [markdown]
# # Create DTM

# %% [markdown]
# ## Load data

# %%
with sqlite3.connect(db_name) as db:
    tokens = pd.read_sql('SELECT * FROM token', db, index_col=OHCO)
    vocab = pd.read_sql('SELECT * FROM vocab', db, index_col='term_id')
    docs =  pd.read_sql('SELECT * FROM doc', db, index_col=AUTHOR)

# %% [markdown]
# ## Create word mask

# %%
WORDS = (tokens.punc == 0) & (tokens.num == 0)

# %% [markdown]
# ## Extract BOW from tokens

# %%
BOW = tokens[WORDS].groupby(BAG + ['term_id'])['term_id'].count()

# %% [markdown]
# ## Convert BOW to DTM

# %%
DTM = BOW.unstack().fillna(0)

# %% [markdown]
# ## Create Bags table

# %%
bags = pd.DataFrame(index = DTM.index)

# %%
DTM = DTM.reset_index(drop=True)
DTM.index.name = 'bag_id'

# %% [markdown]
# # Compute Term Frequencies and Weights

# %% [markdown]
# ## Compute IDF

# %%
N_docs = DTM.shape[0]
vocab['df'] = DTM[DTM > 0].count()
vocab['idf'] = np.log10(N_docs / vocab.df)

# %%
vocab[vocab.stop==0].sort_values('n', ascending=False).head(500)\
    .sort_values('idf', ascending=False).head(20)
# Out:
#            term_str     n         p port_stem  stop     df       idf
# term_id
# 71581          raps   858  0.000175       rap     0  505.0  1.141310
# 88818        techno   969  0.000197    techno     0  535.0  1.116248
# 23539         disco   924  0.000188     disco     0  593.0  1.071547
# 24254            dj   956  0.000195        dj     0  604.0  1.063564
# 86782           sun   917  0.000187       sun     0  614.0  1.056433
# 9516          blues  1024  0.000208      blue     0  616.0  1.055021
# 49029            la  1040  0.000212        la     0  626.0  1.048027
# 88267          talk   913  0.000186      talk     0  648.0  1.033026
# 71533        rapper  1132  0.000230    rapper     0  653.0  1.029688
# 31715          fire   872  0.000177      fire     0  655.0  1.028360
# 72433    recordings   872  0.000177    record     0  656.0  1.027698
# 88445          tape   904  0.000184      tape     0  659.0  1.025716
# 79825          shit   853  0.000174      shit     0  663.0  1.023088
# 100935         york   935  0.000190      york     0  671.0  1.017879
# 2617        ambient   966  0.000197   ambient     0  680.0  1.012093
# 69290     producers   876  0.000178    produc     0  683.0  1.010181
# 33812       friends   889  0.000181    friend     0  688.0  1.007013
# 35804          girl  1044  0.000212      girl     0  692.0  1.004495
# 52850       machine   884  0.000180    machin     0  693.0  1.003868
# 18816       country  1099  0.000224   countri     0  702.0  0.998264

# %% [markdown]
# ## Compute TFIDF

# %%
TFIDF = DTM * vocab['idf']

# %%
vocab[TFIDF.sum() == 0] # test for stop words
# Out:
#          term_str       n             p port_stem  stop      df  idf
# term_id
# 0               a  142517  2.900697e-02         a     1  6992.0  0.0
# 541       acheive       1  2.035334e-07    acheiv     0     NaN  NaN
# 2995          and  138244  2.813727e-02       and     1  6992.0  0.0
# 24851     dossier       1  2.035334e-07   dossier     0     NaN  NaN
# 61931          of  147904  3.010340e-02        of     1  6992.0  0.0
# 89564         the  255840  5.207198e-02       the     1  6992.0  0.0
# 100272   wulfstan       1  2.035334e-07  wulfstan     0     NaN  NaN
# 100597     yatton       1  2.035334e-07    yatton     0     NaN  NaN

# %% [markdown]
# ## Add stats to Vocab

# %%
vocab['tfidf_sum'] = TFIDF.sum()
vocab['tfidf_mean'] = TFIDF.mean()
vocab['tfidf_max'] = TFIDF.max()

# %% [markdown]
# # Get Top words and Trim Matrix

# %%
def get_top_terms(vocab, no_stops=True, sort_col='n', k=1500):
    if no_stops:
        V = vocab[vocab.stop == 0]
    else:
        V = vocab
    return V.sort_values(sort_col, ascending=False).head(k)

# %% [markdown]
# ## Filter proper nouns

# %%
proper_nouns = tokens.loc[tokens.pos == 'NNP', 'term_id'].unique()

# %%
top_n = 1500
# TOPV = get_top_terms(vocab, sort_col='n')
TOPV = get_top_terms(vocab.loc[~vocab.index.isin(proper_nouns)], sort_col='n')
TOPV
# Out:
#               term_str     n         p  port_stem  stop      df       idf  \
# term_id
# 73338         released  2306  0.000469     releas     0  1764.0  0.598103
# 78500             seem  2125  0.000433       seem     0  1715.0  0.610337
# 72221           recent  1552  0.000316     recent     0  1323.0  0.723042
# 50258           length  1387  0.000282     length     0  1233.0  0.753638
# 95436             used  1187  0.000242        use     0  1029.0  0.832186
# 29230          exactly  1128  0.000230    exactli     0   987.0  0.850284
# 82923      songwriting  1061  0.000216   songwrit     0   906.0  0.887473
# 78502           seemed  1009  0.000205       seem     0   835.0  0.922915
# 28166         entirely   884  0.000180      entir     0   789.0  0.947524
# 86634         suggests   869  0.000177    suggest     0   771.0  0.957547
# 61740          obvious   790  0.000161     obviou     0   715.0  0.990295
# 32750        following   773  0.000157     follow     0   705.0  0.996412
# 93082           turned   734  0.000149       turn     0   647.0  1.033697
# 84837          started   701  0.000143      start     0   627.0  1.047334
# 59502        narrative   689  0.000140       narr     0   619.0  1.052911
# 71607           rarely   685  0.000139       rare     0   625.0  1.048721
# 99854           worked   650  0.000132       work     0   602.0  1.065005
# 16429    collaboration   648  0.000132   collabor     0   561.0  1.095639
# 14210        character   645  0.000131    charact     0   553.0  1.101876
# 129            ability   639  0.000130       abil     0   575.0  1.084934
# 86623          suggest   600  0.000122    suggest     0   562.0  1.094865
# 18056         contrast   579  0.000118   contrast     0   543.0  1.109802
# 95454             uses   573  0.000117        use     0   521.0  1.127764
# 16991       compelling   561  0.000114     compel     0   526.0  1.123616
# 65403            peers   552  0.000112       peer     0   514.0  1.133638
# 72188          recalls   534  0.000109      recal     0   504.0  1.142171
# 32601          focused   529  0.000108      focus     0   497.0  1.148245
# 74735         rhythmic   527  0.000107   rhythmic     0   465.0  1.177148
# 35321           genres   516  0.000105       genr     0   450.0  1.191389
# 43126       impressive   501  0.000102    impress     0   461.0  1.180900
# ...                ...   ...       ...        ...   ...     ...       ...
# 80546       signatures    61  0.000012   signatur     0    61.0  2.059272
# 95130       unwavering    61  0.000012      unwav     0    61.0  2.059272
# 72314       recognized    61  0.000012     recogn     0    59.0  2.073749
# 13534         category    61  0.000012   categori     0    58.0  2.081173
# 63654         overdubs    61  0.000012    overdub     0    58.0  2.081173
# 56908         missteps    61  0.000012    misstep     0    60.0  2.066450
# 80264            shrug    61  0.000012      shrug     0    61.0  2.059272
# 9604           bluster    61  0.000012    bluster     0    61.0  2.059272
# 13030        careening    61  0.000012     careen     0    60.0  2.066450
# 988             adrift    61  0.000012     adrift     0    59.0  2.073749
# 61094      notoriously    61  0.000012     notori     0    59.0  2.073749
# 95535            utter    61  0.000012      utter     0    58.0  2.081173
# 4618         ascendant    61  0.000012     ascend     0    61.0  2.059272
# 27069        elegantly    61  0.000012  elegantli     0    60.0  2.066450
# 59406           naming    61  0.000012       name     0    58.0  2.081173
# 90108        thrashing    61  0.000012     thrash     0    61.0  2.059272
# 90347       thundering    61  0.000012    thunder     0    61.0  2.059272
# 68941       prevailing    61  0.000012    prevail     0    61.0  2.059272
# 5929          backbeat    61  0.000012   backbeat     0    61.0  2.059272
# 338           academic    61  0.000012     academ     0    61.0  2.059272
# 78866       separating    61  0.000012      separ     0    59.0  2.073749
# 373             accept    61  0.000012     accept     0    57.0  2.088727
# 17025         compiled    61  0.000012     compil     0    60.0  2.066450
# 16614         colossal    61  0.000012     coloss     0    61.0  2.059272
# 79016         serrated    61  0.000012     serrat     0    61.0  2.059272
# 67283      pleasurable    61  0.000012    pleasur     0    59.0  2.073749
# 24880         doubling    61  0.000012      doubl     0    59.0  2.073749
# 25583         drumbeat    60  0.000012   drumbeat     0    58.0  2.081173
# 74543       revivalism    60  0.000012      reviv     0    58.0  2.081173
# 80224        shrieking    60  0.000012     shriek     0    59.0  2.073749
#
#            tfidf_sum  tfidf_mean  tfidf_max
# term_id
# 73338    1379.225146    0.197258   6.579131
# 78500    1296.966752    0.185493   3.662024
# 72221    1122.160525    0.160492   3.615208
# 50258    1045.296382    0.149499   3.014553
# 95436     987.804835    0.141276   3.328744
# 29230     959.120653    0.137174   3.401137
# 82923     941.609088    0.134669   4.437366
# 78502     931.221179    0.133184   5.537490
# 28166     837.611584    0.119796   2.842573
# 86634     832.108379    0.119009   2.872641
# 61740     782.333348    0.111890   3.961182
# 32750     770.226710    0.110158   3.985649
# 93082     758.733700    0.108515   5.168486
# 84837     734.181049    0.105003   4.189336
# 59502     725.455521    0.103755   6.317465
# 71607     718.374161    0.102742   3.146164
# 99854     692.253203    0.099006   3.195015
# 16429     709.973786    0.101541   5.478193
# 14210     710.710206    0.101646   4.407505
# 129       693.272554    0.099152   3.254801
# 86623     655.824197    0.093796   3.284595
# 18056     642.575121    0.091901   2.219603
# 95454     646.208598    0.092421   3.383291
# 16991     630.348394    0.090153   3.370847
# 65403     625.768342    0.089498   4.534553
# 72188     609.919252    0.087231   3.426513
# 32601     607.421621    0.086874   3.444735
# 74735     619.180094    0.088556   4.708594
# 35321     614.756675    0.087923   4.765556
# 43126     591.631148    0.084615   4.723602
# ...              ...         ...        ...
# 80546     125.615567    0.017966   2.059272
# 95130     125.615567    0.017966   2.059272
# 72314     126.498714    0.018092   4.147499
# 13534     126.951579    0.018157   4.162347
# 63654     126.951579    0.018157   6.243520
# 56908     126.053460    0.018028   4.132900
# 80264     125.615567    0.017966   2.059272
# 9604      125.615567    0.017966   2.059272
# 13030     126.053460    0.018028   4.132900
# 988       126.498714    0.018092   4.147499
# 61094     126.498714    0.018092   4.147499
# 95535     126.951579    0.018157   4.162347
# 4618      125.615567    0.017966   2.059272
# 27069     126.053460    0.018028   4.132900
# 59406     126.951579    0.018157   4.162347
# 90108     125.615567    0.017966   2.059272
# 90347     125.615567    0.017966   2.059272
# 68941     125.615567    0.017966   2.059272
# 5929      125.615567    0.017966   2.059272
# 338       125.615567    0.017966   2.059272
# 78866     126.498714    0.018092   6.221248
# 373       127.412320    0.018223   4.177453
# 17025     126.053460    0.018028   4.132900
# 16614     125.615567    0.017966   2.059272
# 79016     125.615567    0.017966   2.059272
# 67283     126.498714    0.018092   4.147499
# 24880     126.498714    0.018092   4.147499
# 25583     124.870406    0.017859   4.162347
# 74543     124.870406    0.017859   4.162347
# 80224     124.424964    0.017795   4.147499
#
# [1500 rows x 10 columns]

# %% [markdown]
# ## Create tf-idf matrix

# %%
tfidf_small = TFIDF[TOPV.index].stack().to_frame().rename(columns={0:'w'})

# %% [markdown]
# # Save to SQL

# %%
with sqlite3.connect(db_name) as db:
    vocab.to_sql('vocab', db, if_exists='replace', index=True)
    tokens.to_sql('token', db, if_exists='replace', index=True)
    docs.to_sql('doc', db, if_exists='replace', index=True)
    tfidf_small.to_sql('tfidf_small', db, if_exists='replace', index=True)
    bags.reset_index().to_sql('bag', db, if_exists='replace', index=True, index_label='bag_id')

# %% [markdown]
# ## Filter only adjectives

# %%
adjectives = tokens.loc[tokens.pos == 'JJ', 'term_id'].unique()
top_n = 1500
TOPV = get_top_terms(vocab.loc[vocab.index.isin(adjectives)], sort_col='n')
tfidf_small = TFIDF[TOPV.index].stack().to_frame().rename(columns={0:'w'})
TOPV
# Out:
#             term_str      n         p    port_stem  stop      df       idf  \
# term_id
# 50821           like  28205  0.005741         like     0  6676.0  0.020085
# 1863           album  16433  0.003345        album     0  5585.0  0.097578
# 62380            one  14586  0.002969          one     0  5641.0  0.093245
# 58807          music  14489  0.002949        music     0  5180.0  0.130272
# 82802          songs  12412  0.002526         song     0  4914.0  0.153166
# 29039           even   9626  0.001959         even     0  4878.0  0.156360
# 82752           song   9569  0.001948         song     0  4385.0  0.202632
# 83166          sound   9425  0.001918        sound     0  4754.0  0.167542
# 60149            new   9055  0.001843          new     0  4417.0  0.199474
# 6443            band   9050  0.001842         band     0  3402.0  0.312867
# 90572           time   8398  0.001709         time     0  4363.0  0.204816
# 58408           much   7621  0.001551         much     0  4294.0  0.211739
# 31793          first   7617  0.001550        first     0  4269.0  0.214275
# 67927            pop   7355  0.001497          pop     0  3372.0  0.316714
# 72397         record   7321  0.001490       record     0  3824.0  0.262084
# 97926            way   7196  0.001465          way     0  4115.0  0.230232
# 83238         sounds   6926  0.001410        sound     0  3975.0  0.245264
# 75381           rock   6722  0.001368         rock     0  3120.0  0.350447
# 93341            two   6636  0.001351          two     0  3831.0  0.261289
# 85291          still   6520  0.001327        still     0  3793.0  0.265619
# 91651          track   6153  0.001252        track     0  3817.0  0.262879
# 1924          albums   6133  0.001248        album     0  3535.0  0.296212
# 100682         years   6069  0.001235         year     0  3681.0  0.278636
# 40180            hes   5869  0.001195           he     0  2729.0  0.408598
# 89773         theres   5797  0.001180        there     0  3538.0  0.295844
# 2445            also   5758  0.001172         also     0  3570.0  0.291933
# 91695         tracks   5565  0.001133        track     0  3268.0  0.330319
# 37839         guitar   5443  0.001108       guitar     0  3042.0  0.361442
# 99835           work   5443  0.001108         work     0  3320.0  0.323463
# 90046         though   5275  0.001074       though     0  3433.0  0.308928
# ...              ...    ...       ...          ...   ...     ...       ...
# 4722             ask    309  0.000063          ask     0   275.0  1.405269
# 8822            bits    309  0.000063          bit     0   289.0  1.383704
# 85044          steel    309  0.000063        steel     0   259.0  1.431302
# 39887          helps    309  0.000063         help     0   289.0  1.383704
# 46288          jesus    308  0.000063         jesu     0   216.0  1.510148
# 1468      aggressive    308  0.000063      aggress     0   286.0  1.388235
# 27794         ending    308  0.000063          end     0   282.0  1.394352
# 60932          north    308  0.000063        north     0   251.0  1.444928
# 40559           hint    307  0.000062         hint     0   291.0  1.380708
# 93404        typical    307  0.000062        typic     0   276.0  1.403692
# 90175      thrilling    307  0.000062       thrill     0   299.0  1.368930
# 48396        knowing    307  0.000062         know     0   294.0  1.376254
# 41121         honest    307  0.000062       honest     0   278.0  1.400557
# 29751        explore    307  0.000062       explor     0   292.0  1.379219
# 84953         status    307  0.000062        statu     0   285.0  1.389757
# 62954     originally    306  0.000062       origin     0   288.0  1.385209
# 17139    composition    306  0.000062     composit     0   276.0  1.403692
# 68600    predecessor    306  0.000062  predecessor     0   293.0  1.377734
# 58370             mr    306  0.000062           mr     0   195.0  1.554567
# 31236       festival    306  0.000062       festiv     0   261.0  1.427961
# 21840       delivers    305  0.000062        deliv     0   288.0  1.385209
# 79462         shared    305  0.000062        share     0   284.0  1.391283
# 20735         darker    305  0.000062       darker     0   284.0  1.391283
# 85951      strongest    305  0.000062    strongest     0   281.0  1.395895
# 25210          draws    305  0.000062         draw     0   292.0  1.379219
# 10882         breath    305  0.000062       breath     0   277.0  1.402122
# 92396          trick    304  0.000062        trick     0   281.0  1.395895
# 31878           fits    304  0.000062          fit     0   286.0  1.388235
# 55591         merely    304  0.000062         mere     0   295.0  1.374779
# 80532           sign    304  0.000062         sign     0   285.0  1.389757
#
#            tfidf_sum  tfidf_mean  tfidf_max
# term_id
# 50821     566.439754    0.081013   0.441872
# 1863     1603.308097    0.229306   1.853987
# 62380    1359.889745    0.194492   2.237888
# 58807    1887.375808    0.269934   2.996248
# 82802    1901.099712    0.271896   3.063325
# 29039    1504.961378    0.215240   2.189035
# 82752    1938.983904    0.277315   4.863164
# 83166    1578.918091    0.225818   1.842965
# 60149    1805.838306    0.258272   3.790006
# 6443     2830.195880    0.404776   7.195944
# 90572    1720.046503    0.246002   4.505957
# 58408    1613.454072    0.230757   1.905654
# 31793    1631.920417    0.233398   2.785578
# 67927    2329.430394    0.333157   6.650991
# 72397    1917.927317    0.274303   3.669170
# 97926    1656.746450    0.236949   3.683705
# 83238    1698.455185    0.242914   2.452643
# 75381    2354.652221    0.336764   8.410724
# 93341    1733.915580    0.247986   2.874182
# 85291    1731.833122    0.247688   2.921804
# 91651    1617.233206    0.231298   2.891672
# 1924     1816.371993    0.259779   2.962120
# 100682   1690.482198    0.241774   4.179534
# 40180    2397.652383    0.342914   5.311772
# 89773    1715.005297    0.245281   2.662592
# 2445     1680.659453    0.240369   2.335466
# 91695    1837.896985    0.262857   3.303194
# 37839    1967.329949    0.281369   3.975864
# 99835    1760.610937    0.251804   3.881560
# 90046    1629.284248    0.233021   2.471421
# ...              ...         ...        ...
# 4722      434.228036    0.062104   9.836881
# 8822      427.564405    0.061151   4.151111
# 85044     442.272212    0.063254  14.313017
# 39887     427.564405    0.061151   6.918518
# 46288     465.125482    0.066523  25.672510
# 1468      427.576499    0.061152   4.164706
# 27794     429.460512    0.061422   6.971762
# 60932     445.037731    0.063650  10.114494
# 40559     423.877488    0.060623   4.142125
# 93404     430.933548    0.061632   9.825846
# 90175     420.261581    0.060106   2.737860
# 48396     422.510005    0.060428   4.128762
# 41121     429.970883    0.061495   9.803896
# 29751     423.420100    0.060558   2.758437
# 84953     426.655264    0.061020   6.948783
# 62954     423.873933    0.060623   2.770418
# 17139     429.529855    0.061432   5.614769
# 68600     420.208809    0.060099   4.133201
# 58370     475.697443    0.068035  17.100235
# 31236     436.956039    0.062494   8.567765
# 21840     422.488724    0.060425   4.155627
# 79462     424.341339    0.060690   4.173849
# 20735     424.341339    0.060690   8.347698
# 85951     425.748005    0.060891   6.979475
# 25210     420.661663    0.060163   4.137656
# 10882     427.647103    0.061162  11.216973
# 92396     424.352110    0.060691   8.375371
# 31878     422.023557    0.060358   6.941177
# 55591     417.932939    0.059773   4.124338
# 80532     421.096238    0.060225   4.169270
#
# [1500 rows x 10 columns]

# %% [markdown]
# Looks bad!  I checked the adjectives to see if they were filtering properly.

# %%
adjectives = tokens.loc[tokens.pos == 'JJ', 'term_str'].unique()
adjectives_df = pd.DataFrame(adjectives)
adjectives_df
# Out:
#                            0
# 0                   enviable
# 1                       able
# 2                   familiar
# 3                      other
# 4                     little
# 5                     adrift
# 6               contemporary
# 7                  stylistic
# 8                     number
# 9                    scrappy
# 10                       low
# 11                  likeable
# 12                   awkward
# 13                    formed
# 14                      full
# 15                    former
# 16                       old
# 17                   nascent
# 18                    jagged
# 19                   complex
# 20                 different
# 21                   obvious
# 22                    knotty
# 23                     synth
# 24                     right
# 25                      same
# 26                      live
# 27                nihilistic
# 28                forthright
# 29                  straight
# ...                      ...
# 23610               textiles
# 23611       serpentwithfeets
# 23612             yousomeday
# 23613              lightlyhe
# 23614                    job
# 23615                   soil
# 23616    thecontrollersphere
# 23617                 flunkt
# 23618               mouthful
# 23619              ununiform
# 23620              misjudged
# 23621                 google
# 23622          individualist
# 23623  perfectionistannoying
# 23624     natureantagonistic
# 23625                  yeezy
# 23626                  lodge
# 23627                   caps
# 23628               shackled
# 23629                 denote
# 23630              swaggered
# 23631                   wino
# 23632              southwind
# 23633                  sarod
# 23634            adolesecent
# 23635      grrrrrrrrrrrrrrrr
# 23636                  álbum
# 23637              othersand
# 23638                   viva
# 23639                warrant
#
# [23640 rows x 1 columns]

# %% [markdown]
# Looks like adjectives, so I compared a few of the top values that didn't seem like adjectives to see if they were actually coded as adjectives.

# %%
w = ["like", "album", "music", "one", "songs"]
for word in w:
    print(adjectives_df[adjectives_df[0] == word])
# Out:
#          0
# 1114  like
#           0
# 1122  album
#          0
# 286  music
#        0
# 160  one
#          0
# 499  songs

# %% [markdown]
# The words are actually coded as adjectives at least once.  Looks like this is just a case of bad pos tagging.

# %% [markdown]
# ## Save adjectives to db

# %%
with sqlite3.connect(db_name2) as db:
    vocab.to_sql('vocab', db, if_exists='replace', index=True)
    tokens.to_sql('token', db, if_exists='replace', index=True)
    docs.to_sql('doc', db, if_exists='replace', index=True)
    tfidf_small.to_sql('tfidf_small', db, if_exists='replace', index=True)
    bags.reset_index().to_sql('bag', db, if_exists='replace', index=True, index_label='bag_id')
